# %%
# !pip3 install opencv_python
# !pip3 install numpy
# !pip3 install matplotlib
# Out:
# 24295.17s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: opencv_python in /Users/enrique/CV_PC_BRAILLE_OCR/.venv/lib/python3.10/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /Users/enrique/CV_PC_BRAILLE_OCR/.venv/lib/python3.10/site-packages (from opencv_python) (2.1.3)
# 24301.82s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: numpy in /Users/enrique/CV_PC_BRAILLE_OCR/.venv/lib/python3.10/site-packages (2.1.3)
# 24308.17s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: matplotlib in /Users/enrique/CV_PC_BRAILLE_OCR/.venv/lib/python3.10/site-packages (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/enrique/CV_PC_BRAILLE_OCR/.venv/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/enrique/CV_PC_BRAILLE_OCR/.venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/enrique/CV_PC_BRAILLE_OCR/.venv/lib/python3.10/site-packages (from matplotlib) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/enrique/CV_PC_BRAILLE_OCR/.venv/lib/python3.10/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /Users/enrique/CV_PC_BRAILLE_OCR/.venv/lib/python3.10/site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /Users/enrique/CV_PC_BRAILLE_OCR/.venv/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/enrique/CV_PC_BRAILLE_OCR/.venv/lib/python3.10/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/enrique/CV_PC_BRAILLE_OCR/.venv/lib/python3.10/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/enrique/CV_PC_BRAILLE_OCR/.venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/enrique/CV_PC_BRAILLE_OCR/.venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

# %%
# There are some problems in notebooks with cv2 imshow, use matplotlib instead.
# conversion needed
def plt_show(img):
	image_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

	plt.imshow(image_rgb)
	plt.axis('off')
	plt.show()
 
def plt_show2(img1, img2):
    img1_rgb = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
    img2_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
    
    # Create subplots
    fig, axes = plt.subplots(1, 2, figsize=(10, 5))
    axes[0].imshow(img1_rgb)
    axes[0].axis('off')

    axes[1].imshow(img2_rgb)
    axes[1].axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
# Cargar imagen
# image = cv2.imread("../images/tests/test_1.png", cv2.IMREAD_GRAYSCALE)
image = cv2.imread("../images/Angelina/0002.jpg", cv2.IMREAD_GRAYSCALE)
plt_show(image)

# %%
import cv2
import numpy as np

# Load the image
# image = cv2.imread("../images/tests/test_1.png", cv2.IMREAD_GRAYSCALE)

# gray = cv2.bitwise_not(image)
gray = (image)

blurred = cv2.GaussianBlur(gray, (7, 7), 5)
binary_raw = cv2.adaptiveThreshold(blurred, 255, cv2.ADAPTIVE_THRESH_MEAN_C,
                               cv2.THRESH_BINARY, 5, 1)
binary = cv2.medianBlur(binary_raw, 7)

# Show the result
plt_show2(gray, binary)

# %%
num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(cv2.bitwise_not(binary))

areas = []
widths = []
heights = []
aspect_ratios = []
compactness = []
component_indices = []

for i in range(1, num_labels):
    x, y, w, h, area = stats[i]
    cx, cy = centroids[i]

    aspect_ratio = w / h if h != 0 else 0
    perimeter = 2 * (w + h)
    compactness_val = (4 * np.pi * area) / (perimeter ** 2) if perimeter != 0 else 0

    component_indices.append(i)
    areas.append(area)
    widths.append(w)
    heights.append(h)
    aspect_ratios.append(aspect_ratio)
    compactness.append(compactness_val)

properties = {
    "Area": areas,
    "Width": widths,
    "Height": heights,
    "Aspect Ratio": aspect_ratios,
    "Compactness": compactness,
}

filtered_components = {prop_name: [] for prop_name in properties.keys()}

for prop_name, values in properties.items():
    hist, bin_edges = np.histogram(values, bins=100)
    total_elements = len(values)

    threshold = 0.002 * total_elements
    valid_bins = [i for i, count in enumerate(hist) if count >= threshold]

    valid_range = []
    for i in valid_bins:
        valid_range.append((bin_edges[i], bin_edges[i + 1]))

    for i, val in enumerate(values):
        if any(low <= val < high for low, high in valid_range):
            filtered_components[prop_name].append(component_indices[i])

    plt.figure()
    plt.hist(values, bins=100, color='blue', alpha=0.7, edgecolor='black', label="All Data")
    for i in valid_bins:
        plt.axvspan(bin_edges[i], bin_edges[i + 1], color='green', alpha=0.3, label="Valid Bin" if i == valid_bins[0] else "")
    plt.title(f"Histogram of {prop_name}")
    plt.xlabel(prop_name)
    plt.ylabel("Frequency")
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %%
num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(cv2.bitwise_not(binary))

areas = []
widths = []
heights = []
aspect_ratios = []
compactness = []
component_indices = []

for i in range(1, num_labels):
    x, y, w, h, area = stats[i]
    cx, cy = centroids[i]

    aspect_ratio = w / h if h != 0 else 0
    perimeter = 2 * (w + h)
    compactness_val = (4 * np.pi * area) / (perimeter ** 2) if perimeter != 0 else 0

    component_indices.append(i)
    areas.append(area)
    widths.append(w)
    heights.append(h)
    aspect_ratios.append(aspect_ratio)
    compactness.append(compactness_val)

properties = {
    "Area": areas,
    "Width": widths,
    "Height": heights,
    "Aspect Ratio": aspect_ratios,
    "Compactness": compactness,
}

valid_components = {prop_name: [] for prop_name in properties.keys()}

for prop_name, values in properties.items():
    hist, bin_edges = np.histogram(values, bins=20)
    total_elements = len(values)
    
    # Determine bins with less than 1% of elements
    threshold = 0.005 * total_elements
    valid_bins = [i for i, count in enumerate(hist) if count >= threshold]

    valid_range = []
    for i in valid_bins:
        valid_range.append((bin_edges[i], bin_edges[i + 1]))

    for i, val in enumerate(values):
        if any(low <= val < high for low, high in valid_range):
            if np.median(area) >= 100:
                if 0.33 <= aspect_ratios[i] <= 3 and  0.4 < compactness[i] < 0.75:
                    valid_components[prop_name].append(component_indices[i])
            else:
                if 0.45 <= aspect_ratios[i] <= 2.5 and  0.25 < compactness[i] and areas[i] >= 10:
                    valid_components[prop_name].append(component_indices[i])

final_valid_indices = []
for i in range(1, num_labels):
    if all(i in valid_components[prop_name] for prop_name in valid_components):
        
        final_valid_indices.append(i)

filtered_image = np.zeros_like(binary)

for idx in final_valid_indices:
    filtered_image[labels == idx] = 255

filtered_image = cv2.medianBlur(filtered_image, 9)
plt_show2(image, filtered_image)
print(len(final_valid_indices))
# Out:
# 522

# %%
binary_image = filtered_image
original_image = image

kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (1, 1))
dilated_image = cv2.dilate(binary_image, kernel, iterations=1)

num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(dilated_image)

average_intensities = []
for label in range(1, num_labels):
    component_mask = (labels == label)
    component_pixels = original_image[component_mask]
    average_intensity = component_pixels.mean()
    average_intensities.append(average_intensity)

average_intensities = np.array(average_intensities).reshape(-1, 1)

# Fit Gaussian Mixture Model with 2 components
gmm = GaussianMixture(n_components=2, random_state=42)
gmm.fit(average_intensities)

gmm_labels = gmm.predict(average_intensities)

mean_0, mean_1 = gmm.means_.flatten()

group_0_mask = np.zeros_like(binary_image, dtype=np.uint8)
group_1_mask = np.zeros_like(binary_image, dtype=np.uint8)

highlighted_image = np.zeros((original_image.shape[0], original_image.shape[1], 3), dtype=np.uint8)

for label, classification in enumerate(gmm_labels, start=1):
    component_mask = (labels == label)
    if classification == 0:
        group_0_mask[component_mask] = 255
        if average_intensities[label-1] < mean_0:
            highlighted_image[component_mask] = [255, 0, 0]
        else:
            highlighted_image[component_mask] = [0, 255, 0]
    else:
        group_1_mask[component_mask] = 255

group_0_image = cv2.bitwise_and(original_image, original_image, mask=group_0_mask)
group_1_image = cv2.bitwise_and(original_image, original_image, mask=group_1_mask)

x = np.linspace(min(average_intensities), max(average_intensities), 500).reshape(-1, 1)
gmm_probs = np.exp(gmm.score_samples(x))

plt.figure(figsize=(20, 10))

plt.subplot(1, 3, 1)
plt.hist(average_intensities.flatten(), bins=50, color='gray', alpha=0.5, density=True, label="Histogram")
plt.plot(x, gmm_probs, color='red', label="Fitted GMM")
plt.axvline(mean_0, color='blue', linestyle='--', label=f'Mean 0: {mean_0:.2f}')
plt.axvline(mean_1, color='green', linestyle='--', label=f'Mean 1: {mean_1:.2f}')
plt.title('Histogram with Fitted Normal Distributions')
plt.xlabel('Average Intensity')
plt.ylabel('Density')
plt.legend()

plt.subplot(1, 3, 2)
plt.title('Original Image')
plt.imshow(original_image, cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title('Highlighted Group 0: Red/Green')
plt.imshow(highlighted_image)
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
def nearest_neighbor_distances(centroids):
    n = len(centroids)
    distances = []
    for i in range(n):
        dists = np.linalg.norm(centroids - centroids[i], axis=1)
        nearest = np.min(dists[dists > 0])
        distances.append(nearest)
    return np.array(distances)

def filter_points(binary_image, centroids, distances, bins=20, threshold=0.01):
    hist, bin_edges = np.histogram(distances, bins=bins)
    total = np.sum(hist)

    valid_ranges = []
    for i in range(len(bin_edges) - 1):
        if hist[i] >= threshold * total:
            valid_ranges.append((bin_edges[i], bin_edges[i+1]))

    keep_centroids = []
    remove_centroids = []
    for centroid, dist in zip(centroids, distances):
        if any(lower <= dist < upper for lower, upper in valid_ranges):
            keep_centroids.append(centroid)
        else:
            remove_centroids.append(centroid)

    filtered_image = np.zeros_like(binary_image)
    distance_filtered = np.zeros_like(binary_image)

    for c in keep_centroids:
        cv2.circle(filtered_image, (int(c[0]), int(c[1])), 1, 255, -1)
    for c in remove_centroids:
        cv2.circle(distance_filtered, (int(c[0]), int(c[1])), 1, 255, -1)

    return filtered_image, distance_filtered, hist, bin_edges, valid_ranges

binary_image = filtered_image

num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(binary_image)

distances = nearest_neighbor_distances(centroids[1:])  # Exclude background centroid (index 0)

filtered_image2, distance_filtered, hist, bin_edges, valid_ranges = filter_points(binary_image, centroids[1:], distances, bins=20, threshold=0.01)

plt.figure(figsize=(20, 6))

plt.subplot(1, 4, 1)
plt.imshow(binary_image, cmap='gray')
plt.title("Original Image")
plt.axis('off')

plt.subplot(1, 4, 2)
plt.imshow(filtered_image2, cmap='gray')
plt.title("Filtered Image")
plt.axis('off')

plt.subplot(1, 4, 3)
plt.imshow(distance_filtered, cmap='gray')
plt.title("Distance Filtered Image")
plt.axis('off')

plt.subplot(1, 4, 4)
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
plt.bar(bin_centers, hist, width=np.diff(bin_edges), edgecolor='black', alpha=0.7, label='All Bins')

# Highlight valid bins
for lower, upper in valid_ranges:
    mask = (bin_centers >= lower) & (bin_centers < upper)
    plt.bar(bin_centers[mask], hist[mask], width=np.diff(bin_edges)[0], color='orange', label='Valid Bins')

plt.title("Histogram of Distances")
plt.xlabel("Distance")
plt.ylabel("Frequency")
plt.legend()

plt.tight_layout()
plt.show()

# %%
contours, _ = cv2.findContours(filtered_image2, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
fig, ax = plt.subplots()

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
ax.imshow(image_rgb)
ax.axis('off')

circularity_threshold = 0.1

# Iterate through contours
for contour in contours:
    area = cv2.contourArea(contour)
    perimeter = cv2.arcLength(contour, closed=True)
    
    if perimeter > 0:
        circularity = 4 * np.pi * (area / (perimeter ** 2))
        
        if circularity >= circularity_threshold:
            contour = contour.squeeze()
            ax.plot(contour[:, 0], contour[:, 1], color='red', linewidth=1)

plt.show()

# %%
# print(centroids)
# np.save('centroids.npy', centroids)
# Out:
# [[ 512.11304795  688.05670808]
#  [  22.5          42.5       ]
#  [ 758.52941176  161.67320261]
#  [ 194.44339623  165.55660377]
#  [ 560.5         191.5       ]
#  [ 580.25        190.75      ]
#  [ 627.34615385  190.34615385]
#  [ 647.04        190.4       ]
#  [ 165.72727273  192.84848485]
#  [ 198.36363636  194.88636364]
#  [ 263.59259259  192.74074074]
#  [ 316.5         193.        ]
#  [ 350.          192.        ]
#  [ 363.5         192.        ]
#  [ 382.84615385  192.61538462]
#  [ 415.5         192.5       ]
#  [ 429.          192.        ]
#  [ 461.61538462  192.38461538]
#  [ 514.5         191.71428571]
#  [ 528.          191.        ]
#  [  89.08333333  196.44444444]
#  [ 121.          195.        ]
#  [ 218.5         194.5       ]
#  [ 660.75        203.25      ]
#  [ 680.8         202.5       ]
#  [ 693.71428571  202.5       ]
#  [ 329.6875      205.5625    ]
#  [ 428.79166667  205.79166667]
#  [ 546.91304348  205.7826087 ]
#  [ 613.5         204.5       ]
#  [ 133.70967742  208.16129032]
#  [ 185.175       208.05      ]
#  [ 250.66666667  207.41025641]
#  [ 349.          206.        ]
#  [ 363.15789474  206.15789474]
#  [ 396.11111111  205.72222222]
#  [ 462.          206.        ]
#  [ 580.          205.        ]
#  [ 153.5         207.71428571]
#  [ 167.          208.        ]
#  [ 626.75        217.25      ]
#  [ 692.58823529  215.88235294]
#  [ 218.65384615  219.34615385]
#  [ 316.5         219.        ]
#  [ 350.40740741  219.74074074]
#  [ 514.5         218.8       ]
#  [ 547.5         217.5       ]
#  [ 580.28571429  218.5       ]
#  [ 613.28571429  217.5       ]
#  [  89.25925926  220.40740741]
#  [ 416.          219.5       ]
#  [ 448.2173913   220.91304348]
#  [ 461.5         220.27272727]
#  [ 120.88235294  221.58823529]
#  [ 153.7826087   221.91304348]
#  [ 218.66666667  253.77777778]
#  [ 166.5         254.        ]
#  [ 185.5         255.        ]
#  [ 199.5         253.5       ]
#  [  89.5         256.5       ]
#  [ 121.          256.        ]
#  [ 140.41176471  256.88235294]
#  [ 154.          255.5       ]
#  [ 170.          268.        ]
#  [  89.22222222  281.5       ]
#  [ 219.          281.        ]
#  [ 168.85714286  316.19047619]
#  [ 383.          316.53571429]
#  [ 463.          316.        ]
#  [ 512.63333333  316.36666667]
#  [  90.15789474  318.84210526]
#  [ 121.72222222  318.11111111]
#  [ 154.5         318.27272727]
#  [ 186.7826087   317.91304348]
#  [ 219.13636364  318.        ]
#  [ 317.5         318.2       ]
#  [ 349.5         318.28571429]
#  [ 415.5         317.71428571]
#  [ 480.70833333  318.        ]
#  [ 135.85365854  330.31707317]
#  [ 429.5         330.        ]
#  [ 251.84210526  331.15789474]
#  [ 364.4         330.6       ]
#  [ 382.5         330.5       ]
#  [ 397.5         330.5       ]
#  [ 448.          330.        ]
#  [ 462.13636364  330.68181818]
#  [ 169.22222222  331.5       ]
#  [ 546.5         342.28571429]
#  [  90.76190476  345.04761905]
#  [ 155.5         344.71428571]
#  [ 317.          344.5       ]
#  [ 382.5         344.71428571]
#  [ 415.61538462  344.61538462]
#  [ 461.25925926  345.40740741]
#  [ 122.          344.5       ]
#  [ 350.          344.5       ]
#  [ 362.5         344.8       ]
#  [ 169.5         377.78571429]
#  [ 201.88571429  377.74285714]
#  [  91.5         379.5       ]
#  [ 122.5         379.2       ]
#  [ 155.38461538  379.38461538]
#  [ 136.40740741  391.74074074]
#  [ 169.          392.5       ]
#  [ 201.875       392.125     ]
#  [ 154.5         392.5       ]
#  [  91.75        405.375     ]
#  [ 123.05        405.9       ]
#  [ 155.86363636  407.        ]
#  [ 187.5         406.71428571]
#  [ 201.22222222  406.5       ]
#  [ 254.          438.5       ]
#  [ 268.98181818  439.07272727]
#  [ 105.5         439.78571429]
#  [ 170.5         439.5       ]
#  [  92.16666667  439.91666667]
#  [ 123.6         441.04      ]
#  [ 187.5         440.71428571]
#  [ 220.          440.5       ]
#  [ 138.17073171  451.7804878 ]
#  [ 105.23809524  454.04761905]
#  [ 234.5         454.5       ]
#  [ 267.5         454.5       ]
#  [  92.          454.5       ]
#  [ 156.          467.5       ]
#  [ 220.5         467.5       ]
#  [ 139.21052632  499.63157895]
#  [ 106.          501.29166667]
#  [ 234.5         502.71428571]
#  [ 788.57142857  502.        ]
#  [ 808.5         502.5       ]
#  [ 841.71428571  501.5       ]
#  [ 253.15789474  504.15789474]
#  [ 364.          503.        ]
#  [ 383.61538462  503.61538462]
#  [ 428.5         504.        ]
#  [ 493.58823529  503.88235294]
#  [ 512.5         504.        ]
#  [ 545.5         503.71428571]
#  [ 623.          503.69230769]
#  [ 656.125       503.125     ]
#  [ 675.5         503.        ]
#  [ 105.15789474  513.84210526]
#  [ 855.5         513.71428571]
#  [ 124.          516.        ]
#  [ 655.5         516.        ]
#  [ 755.5         516.        ]
#  [ 788.5         516.        ]
#  [ 331.          517.        ]
#  [ 363.5         517.        ]
#  [ 415.5         516.5       ]
#  [ 492.5         517.        ]
#  [ 623.5         517.        ]
#  [ 105.15789474  528.15789474]
#  [ 188.5         528.5       ]
#  [ 221.27777778  528.88888889]
#  [ 234.28571429  528.5       ]
#  [ 331.5         530.        ]
#  [ 364.5         530.        ]
#  [ 480.          530.        ]
#  [ 642.5         529.71428571]
#  [ 655.71428571  529.5       ]
#  [ 774.5         529.2       ]
#  [ 787.36363636  528.90909091]
#  [ 106.          564.        ]
#  [ 125.          564.        ]
#  [ 137.5         564.        ]
#  [ 202.5         564.5       ]
#  [ 157.5         564.5       ]
#  [ 189.21052632  566.        ]
#  [ 222.          565.5       ]
#  [ 235.34615385  566.34615385]
#  [ 299.5         566.77777778]
#  [ 383.5         567.5       ]
#  [ 415.58064516  567.93548387]
#  [ 364.6         567.6       ]
#  [ 448.          568.        ]
#  [ 512.5         568.        ]
#  [ 525.5         567.71428571]
#  [ 545.25        567.75      ]
#  [ 590.          568.        ]
#  [ 642.          568.        ]
#  [ 655.5         568.5       ]
#  [ 675.25        568.25      ]
#  [ 707.71428571  568.5       ]
#  [ 721.5         567.5       ]
#  [ 741.5         568.        ]
#  [ 774.5         568.        ]
#  [ 105.5         576.5       ]
#  [ 137.5         577.28571429]
#  [ 202.          578.        ]
#  [ 222.          578.5       ]
#  [ 287.          579.29166667]
#  [ 428.71428571  579.5       ]
#  [ 557.5         581.        ]
#  [ 577.          581.2       ]
#  [ 642.5         581.        ]
#  [ 688.5         582.        ]
#  [ 720.71428571  581.5       ]
#  [ 740.5         581.        ]
#  [ 126.12820513  592.12820513]
#  [ 235.08695652  591.7826087 ]
#  [ 351.91304348  592.7826087 ]
#  [ 428.5         593.5       ]
#  [ 512.          594.5       ]
#  [ 544.5         594.        ]
#  [ 642.          594.5       ]
#  [ 675.          594.2       ]
#  [ 740.5         594.28571429]
#  [ 773.61538462  594.38461538]
#  [ 787.26666667  595.33333333]
#  [ 138.20833333  623.79166667]
#  [  92.8         623.5       ]
#  [  92.84210526  638.15789474]
#  [ 124.5         637.        ]
#  [ 162.91578947  638.90526316]
#  [ 170.15789474  651.15789474]
#  [ 106.53333333  684.86666667]
#  [ 138.5         684.5       ]
#  [ 158.2173913   685.91304348]
#  [ 222.5         685.5       ]
#  [ 235.5         685.5       ]
#  [ 286.83333333  685.91666667]
#  [ 300.          686.        ]
#  [ 319.          686.        ]
#  [ 364.28571429  686.5       ]
#  [ 415.38461538  686.61538462]
#  [ 447.5         687.5       ]
#  [ 492.          687.        ]
#  [ 511.5         688.28571429]
#  [ 543.5         687.5       ]
#  [ 621.5         688.5       ]
#  [ 640.63157895  688.21052632]
#  [ 687.          688.        ]
#  [ 706.5         688.        ]
#  [ 739.15789474  689.15789474]
#  [ 772.5         688.5       ]
#  [ 806.          688.5       ]
#  [ 556.5         688.5       ]
#  [ 673.5         688.5       ]
#  [ 106.27777778  698.88888889]
#  [ 125.          699.        ]
#  [ 139.          698.        ]
#  [ 222.28571429  698.5       ]
#  [ 332.          698.64705882]
#  [ 351.          699.        ]
#  [ 427.71428571  699.5       ]
#  [ 460.5         701.        ]
#  [ 479.          701.35294118]
#  [ 492.5         700.        ]
#  [ 772.5         700.5       ]
#  [ 543.5         700.8       ]
#  [ 653.61538462  701.38461538]
#  [ 686.5         702.28571429]
#  [ 705.5         701.        ]
#  [ 719.11764706  701.58823529]
#  [ 786.          701.        ]
#  [ 838.5         702.        ]
#  [ 853.          701.5       ]
#  [ 138.5         711.        ]
#  [ 235.5         711.22222222]
#  [ 189.71428571  711.5       ]
#  [ 287.          711.8       ]
#  [ 319.          712.        ]
#  [ 364.          711.64705882]
#  [ 415.25        712.75      ]
#  [ 447.31818182  712.86363636]
#  [ 556.2         713.5       ]
#  [ 492.          713.5       ]
#  [ 607.75        714.75      ]
#  [ 640.5         714.        ]
#  [ 705.88888889  715.27777778]
#  [ 852.          715.        ]
#  [ 738.88235294  715.58823529]
#  [ 752.61538462  715.38461538]
#  [  11.46153846  736.53846154]
#  [ 106.5         744.        ]
#  [ 125.5         745.5       ]
#  [ 138.34615385  744.34615385]
#  [ 299.75        744.75      ]
#  [ 331.72222222  745.11111111]
#  [ 170.84210526  745.84210526]
#  [ 222.71428571  745.5       ]
#  [ 254.5         745.        ]
#  [ 351.09090909  745.36363636]
#  [ 396.5         746.        ]
#  [ 447.25        746.75      ]
#  [ 511.          747.        ]
#  [ 479.28571429  747.5       ]
#  [ 542.35294118  748.        ]
#  [ 555.          747.        ]
#  [ 575.41176471  748.11764706]
#  [ 607.5         748.5       ]
#  [ 686.          749.        ]
#  [ 752.5         749.5       ]
#  [ 640.          749.        ]
#  [ 719.5         749.        ]
#  [ 771.75        749.75      ]
#  [ 158.          758.        ]
#  [ 286.5         758.        ]
#  [ 318.5         758.5       ]
#  [ 351.          758.        ]
#  [ 382.78571429  760.5       ]
#  [ 491.65384615  760.34615385]
#  [ 555.58823529  760.88235294]
#  [ 620.5         762.28571429]
#  [ 639.625       761.75      ]
#  [ 687.          762.8       ]
#  [ 719.          762.        ]
#  [ 738.5         762.        ]
#  [ 819.26666667  763.33333333]
#  [ 705.          763.        ]
#  [ 804.5         764.28571429]
#  [ 106.5         770.5       ]
#  [ 125.5         769.5       ]
#  [ 158.          771.5       ]
#  [ 171.          771.5       ]
#  [ 222.11764706  771.58823529]
#  [ 254.28571429  771.5       ]
#  [ 267.5         771.28571429]
#  [ 286.5         771.77777778]
#  [ 351.28571429  771.5       ]
#  [ 447.21052632  772.36842105]
#  [ 478.65384615  772.65384615]
#  [ 542.5         773.27272727]
#  [ 510.5         773.5       ]
#  [ 574.75        773.75      ]
#  [ 607.5         774.5       ]
#  [ 639.5         775.28571429]
#  [ 672.5         775.71428571]
#  [ 686.          775.        ]
#  [ 705.          775.5       ]
#  [ 771.          775.5       ]
#  [ 818.          777.        ]
#  [ 107.          804.        ]
#  [ 125.5         804.        ]
#  [ 138.5         804.5       ]
#  [ 235.5         804.28571429]
#  [ 254.5         805.28571429]
#  [ 363.6         805.4       ]
#  [ 383.          805.        ]
#  [ 396.5         806.        ]
#  [ 460.          806.        ]
#  [ 588.          807.        ]
#  [ 491.5         807.        ]
#  [ 608.          808.        ]
#  [ 718.91666667  809.83333333]
#  [ 738.5         810.        ]
#  [ 784.5         809.71428571]
#  [ 125.58823529  818.11764706]
#  [ 189.5         818.        ]
#  [ 203.          817.8       ]
#  [ 383.28571429  819.5       ]
#  [ 478.5         820.27272727]
#  [ 542.5         820.        ]
#  [ 556.          821.        ]
#  [ 685.5         823.22222222]
#  [ 718.5         822.        ]
#  [ 671.5         823.        ]
#  [ 770.71428571  823.5       ]
#  [  94.          831.        ]
#  [ 107.35294118  830.        ]
#  [ 190.          830.        ]
#  [ 222.5         830.5       ]
#  [ 235.          830.        ]
#  [ 318.          831.5       ]
#  [ 331.58823529  831.88235294]
#  [ 351.46666667  831.86666667]
#  [ 363.61538462  831.61538462]
#  [ 446.58823529  832.11764706]
#  [ 459.84210526  832.84210526]
#  [ 542.5         833.5       ]
#  [ 574.88888889  833.72222222]
#  [ 588.          834.        ]
#  [ 685.5         836.        ]
#  [ 705.          835.5       ]
#  [ 718.28571429  835.5       ]
#  [ 139.08333333  862.83333333]
#  [ 107.          863.        ]
#  [ 158.          864.29166667]
#  [ 202.8         863.5       ]
#  [ 222.28571429  864.5       ]
#  [ 253.5         865.        ]
#  [ 299.5         864.        ]
#  [ 318.09090909  864.36363636]
#  [ 331.15789474  864.15789474]
#  [ 382.71428571  864.5       ]
#  [ 491.5         865.        ]
#  [ 286.5         864.8       ]
#  [ 414.28571429  865.5       ]
#  [ 446.6         865.6       ]
#  [ 478.28571429  866.5       ]
#  [ 542.25        866.75      ]
#  [ 574.72222222  867.11111111]
#  [ 620.5         867.        ]
#  [ 607.          867.5       ]
#  [ 639.25        867.75      ]
#  [ 685.6         868.4       ]
#  [ 783.625       870.75      ]
#  [ 803.29166667  871.        ]
#  [ 850.2         870.5       ]
#  [ 128.45454545  876.27272727]
#  [ 106.71428571  876.5       ]
#  [ 235.46666667  877.13333333]
#  [ 266.61538462  876.61538462]
#  [ 299.09090909  876.36363636]
#  [ 171.          877.5       ]
#  [ 189.5         877.28571429]
#  [ 318.5         877.        ]
#  [ 395.15789474  878.15789474]
#  [ 427.28571429  878.5       ]
#  [ 459.5         879.        ]
#  [ 555.15789474  880.15789474]
#  [ 587.61538462  879.38461538]
#  [ 652.08695652  881.2173913 ]
#  [ 672.          880.8       ]
#  [ 718.07142857  881.85714286]
#  [ 704.3125      884.9375    ]
#  [ 835.875       883.125     ]
#  [ 849.28571429  884.5       ]
#  [ 125.5         887.71428571]
#  [ 222.28571429  889.5       ]
#  [ 286.10714286  890.71428571]
#  [ 331.08695652  890.7826087 ]
#  [ 478.          892.        ]
#  [ 574.5         892.5       ]
#  [ 607.          893.29166667]
#  [ 638.89655172  893.51724138]
#  [ 671.71428571  894.5       ]
#  [ 685.36363636  895.09090909]
#  [ 718.          895.        ]
#  [ 770.          896.5       ]
#  [ 123.46511628  925.93023256]
#  [ 131.43478261  934.17391304]
#  [1021.68421053 1190.81578947]
#  [ 188.9        1281.43      ]
#  [ 980.5        1283.5       ]
#  [ 734.55140187 1293.6635514 ]]

# %%
# Calculate the mean nearest-neighbor distance
def mean_nearest_neighbor_distance(points):
    n = points.shape[0]
    distances = np.zeros(n)

    for i in range(n):
        # Compute distances from point i to all other points
        dist_to_all = np.linalg.norm(points - points[i], axis=1)
        # Find the nearest neighbor distance (ignoring itself)
        distances[i] = np.min(dist_to_all[dist_to_all > 0])
    
    return np.mean(distances), np.median(distances)

mean_distance, median_distance = mean_nearest_neighbor_distance(centroids)
print(f"Mean/Median nearest-neighbor distance: {mean_distance} {median_distance}")
# Out:
# Mean/Median nearest-neighbor distance: 18.86394847302841 14.382146848060756

# %%
img = image.copy()
assert img is not None, "file could not be read, check with os.path.exists()"
img = cv2.GaussianBlur(image, (7, 7), 5)
 
ret,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,17,5)
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,9,1)
 
titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]

plt.figure(figsize=(7, 5), dpi=350)
for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
    
plt.savefig('subplot_image.png', dpi=350)

plt.show()

# %%
# Preprocesamiento
img = image.copy()
assert img is not None, "file could not be read, check with os.path.exists()"
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
ret,thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
ret,thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)
 
titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]
 
plt.figure(figsize=(10, 5), dpi=350)
for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray',vmin=0,vmax=255)
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.savefig('subplot_image.png', dpi=350)

plt.show()

# %%
# # Load the image
# img_gray = binary_raw
# # Apply different filters
# filters = {
#     "Original": img_gray,
#     "Gaussian Blur (11x11)": cv2.GaussianBlur(img_gray, (11, 11), 0),
#     "Median Blur (11x11)": cv2.medianBlur(img_gray, 11),
#     "Bilateral Filter (9,75,75)": cv2.bilateralFilter(img_gray, 13, 75, 75),
#     "Box Filter (5x5)": cv2.blur(img_gray, (15, 15)),
#     "Sobel X": cv2.Sobel(img_gray, cv2.CV_64F, 1, 0, ksize=11),
#     "Sobel Y": cv2.Sobel(img_gray, cv2.CV_64F, 0, 1, ksize=5),
#     "Laplacian": cv2.Laplacian(img_gray, cv2.CV_64F)
# }

# # Create subplots
# num_filters = len(filters)
# plt.figure(figsize=(15, 10))

# for i, (title, filtered_image) in enumerate(filters.items(), 1):
#     plt.subplot(2, (num_filters + 1) // 2, i)
    
#     # Handle gradient images separately for visualization
#     if title in ["Sobel X", "Sobel Y", "Laplacian"]:
#         filtered_image = cv2.convertScaleAbs(filtered_image)
    
#     plt.imshow(filtered_image, cmap='gray')
#     plt.title(title)
#     plt.axis('off')

# # Display all the filters
# plt.tight_layout()
# plt.show()
